# %%
import random
import pandas as pd
import types
import re
from dateutil.parser import parse

Dict_query_type_mapping={
    "tsnchange:County":"COUNTY",
    "time:Interval":"DATE",
    "geo:Geometry":"GEOMETRY",
    "tsnchange:Change":"CHANGE",
    "sem:Event":"EVENT",
    'tsnchange:State':"STATE"
}

Dict_instances_type_mapping={
    "tsnchange:County":"COUNTY_NAME",
    "time:Interval":"DATE_NAME",
    'tsnchange:State':"STATE_NAME",
    "tsnchange:Change":"CHANGE_TYPE"
}

# %%
data = pd.read_json("./queries_with_results2.json")
pd.options.display.max_colwidth = 500
print(data.head())
# Out:
#   class_changes filters  leaf_nodes  \
# 0            []      []       [?x0]
# 1            []      []       [?x2]
# 2            []      []  [?x0, ?x2]
# 3            []      []       [?x0]
# 4            []      []  [?x2, ?x3]
#
#                                                                                                         node_types  \
# 0                            {'?x0': 'tsnchange:County', '?x1': 'tsnchange:CountyVersion', '?x2': 'time:Interval'}
# 1                             {'?x0': 'tsnchange:County', '?x1': 'tsnchange:CountyVersion', '?x2': 'geo:Geometry'}
# 2     {'?x0': 'tsnchange:County', '?x1': 'tsnchange:CountyVersion', '?x2': 'time:Interval', '?x3': 'geo:Geometry'}
# 3                         {'?x0': 'tsnchange:County', '?x1': 'tsnchange:CountyVersion', '?x2': 'tsnchange:Change'}
# 4  {'?x0': 'tsnchange:County', '?x1': 'tsnchange:CountyVersion', '?x2': 'geo:Geometry', '?x3': 'tsnchange:Change'}
#
#                                                                                                              placeholders  \
# 0                              {'tsnchange:County_0': '?x0', 'tsnchange:CountyVersion_0': '?x1', 'time:Interval_0': '?s'}
# 1                               {'tsnchange:County_0': '?s', 'tsnchange:CountyVersion_0': '?x1', 'geo:Geometry_0': '?x2'}
# 2     {'tsnchange:County_0': '?x0', 'tsnchange:CountyVersion_0': '?x1', 'time:Interval_0': '?x2', 'geo:Geometry_0': '?s'}
# 3                           {'tsnchange:County_0': '?x0', 'tsnchange:CountyVersion_0': '?x1', 'tsnchange:Change_0': '?s'}
# 4  {'tsnchange:County_0': '?s', 'tsnchange:CountyVersion_0': '?x1', 'geo:Geometry_0': '?x2', 'tsnchange:Change_0': '?x3'}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            query_graph  \
# 0                                                     {'edges': [['?x0', 'tsn:hasCountyVersion', '?x1'], ['?x1', 'tsn:referencePeriod', '?s']], 'nodes': [{'placeholder': '?x0', 'type': 'tsnchange:County', 'indexed_type': 'tsnchange:County_0'}, {'placeholder': '?x1', 'type': 'tsnchange:CountyVersion', 'indexed_type': 'tsnchange:CountyVersion_0'}, {'placeholder': '?s', 'type': 'time:Interval', 'indexed_type': 'time:Interval_0', 'uri': 'http://time-space-event.com/resource/county/interval/id/7060'}]}
# 1                                                             {'edges': [['?s', 'tsn:hasCountyVersion', '?x1'], ['?x1', 'geo:hasGeometry', '?x2']], 'nodes': [{'placeholder': '?s', 'type': 'tsnchange:County', 'indexed_type': 'tsnchange:County_0', 'uri': 'http://time-space-event.com/resource/Texas/County/TX_NCA_5'}, {'placeholder': '?x1', 'type': 'tsnchange:CountyVersion', 'indexed_type': 'tsnchange:CountyVersion_0'}, {'placeholder': '?x2', 'type': 'geo:Geometry', 'indexed_type': 'geo:Geometry_0'}]}
# 2  {'edges': [['?x0', 'tsn:hasCountyVersion', '?x1'], ['?x1', 'tsn:referencePeriod', '?x2'], ['?x1', 'geo:hasGeometry', '?s']], 'nodes': [{'placeholder': '?x0', 'type': 'tsnchange:County', 'indexed_type': 'tsnchange:County_0'}, {'placeholder': '?x1', 'type': 'tsnchange:CountyVersion', 'indexed_type': 'tsnchange:CountyVersion_0'}, {'placeholder': '?x2', 'type': 'time:Interval', 'indexed_type': 'time:Interval_0'}, {'placeholder': '?s', 'type': 'geo:Geometry', 'indexed_type': 'geo:Geometry_0', 'ur...
# 3                                 {'edges': [['?x0', 'tsn:hasCountyVersion', '?x1'], ['?x1', 'tsnchange:countyVersionAfter', '?s']], 'nodes': [{'placeholder': '?x0', 'type': 'tsnchange:County', 'indexed_type': 'tsnchange:County_0'}, {'placeholder': '?x1', 'type': 'tsnchange:CountyVersion', 'indexed_type': 'tsnchange:CountyVersion_0'}, {'placeholder': '?s', 'type': 'tsnchange:Change', 'indexed_type': 'tsnchange:Change_0', 'uri': 'http://time-space-event.com/resource/South_Carolina/change_YORK_3'}]}
# 4  {'edges': [['?s', 'tsn:hasCountyVersion', '?x1'], ['?x1', 'geo:hasGeometry', '?x2'], ['?x1', 'tsnchange:countyVersionAfter', '?x3']], 'nodes': [{'placeholder': '?s', 'type': 'tsnchange:County', 'indexed_type': 'tsnchange:County_0', 'uri': 'http://time-space-event.com/resource/Southwest_Territory/County/SEVIER'}, {'placeholder': '?x1', 'type': 'tsnchange:CountyVersion', 'indexed_type': 'tsnchange:CountyVersion_0'}, {'placeholder': '?x2', 'type': 'geo:Geometry', 'indexed_type': 'geo:Geometry_0...
#
#                                                                                                                                                                                                                                                                                                                    results  \
# 0                                                                                                                                                                     [{'?x0': {'value': 'http://time-space-event.com/resource/South_Dakota/County/WAGNER_(ext)', 'type': 'tsnchange:County', 'literal_data_type': None}}]
# 1                                                                                                                                                                   [{'?x2': {'value': 'http://time-space-event.com/resource/Texas/County/TX_NCA_5_1/Geometry/15276', 'type': 'geo:Geometry', 'literal_data_type': None}}]
# 2                                         [{'?x0': {'value': 'http://time-space-event.com/resource/Alabama/County/MORGAN', 'type': 'tsnchange:County', 'literal_data_type': None}, '?x2': {'value': 'http://time-space-event.com/resource/county/interval/id/13890', 'type': 'time:Interval', 'literal_data_type': None}}]
# 3                                                                                                                                                                           [{'?x0': {'value': 'http://time-space-event.com/resource/South_Carolina/County/YORK', 'type': 'tsnchange:County', 'literal_data_type': None}}]
# 4  [{'?x2': {'value': 'http://time-space-event.com/resource/Southwest_Territory/County/SEVIER_2/Geometry/14440', 'type': 'geo:Geometry', 'literal_data_type': None}, '?x3': {'value': 'http://time-space-event.com/resource/Southwest_Territory/change_SEVIER_2', 'type': 'tsnchange:Change', 'literal_data_type': None}}]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   rule  \
# 0  {'edges': [['tsnchange:County_0', 'tsnchange:CountyVersion_0'], ['tsnchange:CountyVersion_0', 'time:Interval_0']], 'graph': ['tsnchange:County_0', 'tsnchange:CountyVersion_0', 'time:Interval_0'], 'id': 'Q1', 'paths': [['tsnchange:County_0', 'tsnchange:CountyVersion_0', 'time:Interval_0']], 'query': 'ASK WHERE {
# { <tsnchange:County_0> ?p <tsnchange:CountyVersion_0>. } UNION {<tsnchange:CountyVersion_0> ?p <tsnchange:County_0>. }
# { <tsnchange:CountyVersion_0> ?p <time:Interval_0>. } UNION {<ti...
# 1  {'edges': [['tsnchange:County_0', 'tsnchange:CountyVersion_0'], ['tsnchange:CountyVersion_0', 'geo:Geometry_0']], 'graph': ['tsnchange:County_0', 'tsnchange:CountyVersion_0', 'geo:Geometry_0'], 'id': 'Q2', 'paths': [['tsnchange:County_0', 'tsnchange:CountyVersion_0', 'geo:Geometry_0']], 'query': 'ASK WHERE {
# { <tsnchange:County_0> ?p <tsnchange:CountyVersion_0>. } UNION {<tsnchange:CountyVersion_0> ?p <tsnchange:County_0>. }
# { <tsnchange:CountyVersion_0> ?p <geo:Geometry_0>. } UNION {<geo:Ge...
# 2  {'edges': [['tsnchange:County_0', 'tsnchange:CountyVersion_0'], ['tsnchange:CountyVersion_0', 'time:Interval_0'], ['tsnchange:CountyVersion_0', 'geo:Geometry_0']], 'graph': ['tsnchange:County_0', 'tsnchange:CountyVersion_0', 'time:Interval_0', 'geo:Geometry_0'], 'id': 'Q3', 'paths': [['tsnchange:County_0', 'tsnchange:CountyVersion_0', 'time:Interval_0'], ['tsnchange:CountyVersion_0', 'geo:Geometry_0']], 'query': 'ASK WHERE {
# { <tsnchange:County_0> ?p <tsnchange:CountyVersion_0>. } UNION {<ts...
# 3  {'edges': [['tsnchange:County_0', 'tsnchange:CountyVersion_0'], ['tsnchange:CountyVersion_0', 'tsnchange:Change_0']], 'graph': ['tsnchange:County_0', 'tsnchange:CountyVersion_0', 'tsnchange:Change_0'], 'id': 'Q4', 'paths': [['tsnchange:County_0', 'tsnchange:CountyVersion_0', 'tsnchange:Change_0']], 'query': 'ASK WHERE {
# { <tsnchange:County_0> ?p <tsnchange:CountyVersion_0>. } UNION {<tsnchange:CountyVersion_0> ?p <tsnchange:County_0>. }
# { <tsnchange:CountyVersion_0> ?p <tsnchange:Change_0>. ...
# 4  {'edges': [['tsnchange:County_0', 'tsnchange:CountyVersion_0'], ['tsnchange:CountyVersion_0', 'geo:Geometry_0'], ['tsnchange:CountyVersion_0', 'tsnchange:Change_0']], 'graph': ['tsnchange:County_0', 'tsnchange:CountyVersion_0', 'geo:Geometry_0', 'tsnchange:Change_0'], 'id': 'Q7', 'paths': [['tsnchange:County_0', 'tsnchange:CountyVersion_0', 'geo:Geometry_0'], ['tsnchange:CountyVersion_0', 'tsnchange:Change_0']], 'query': 'ASK WHERE {
# { <tsnchange:County_0> ?p <tsnchange:CountyVersion_0>. } U...
#
#                                                                             rule_graph  \
# 0                     [tsnchange:County_0, tsnchange:CountyVersion_0, time:Interval_0]
# 1                      [tsnchange:County_0, tsnchange:CountyVersion_0, geo:Geometry_0]
# 2     [tsnchange:County_0, tsnchange:CountyVersion_0, time:Interval_0, geo:Geometry_0]
# 3                  [tsnchange:County_0, tsnchange:CountyVersion_0, tsnchange:Change_0]
# 4  [tsnchange:County_0, tsnchange:CountyVersion_0, geo:Geometry_0, tsnchange:Change_0]
#
#                                                                                                                                                                                                                                                  rule_graph_edges  \
# 0                                                                                          [[tsnchange:County_0, tsnchange:CountyVersion_0, {'uris': ['tsn:hasCountyVersion']}], [tsnchange:CountyVersion_0, time:Interval_0, {'uris': ['tsn:referencePeriod']}]]
# 1                                                                                               [[tsnchange:County_0, tsnchange:CountyVersion_0, {'uris': ['tsn:hasCountyVersion']}], [tsnchange:CountyVersion_0, geo:Geometry_0, {'uris': ['geo:hasGeometry']}]]
# 2              [[tsnchange:County_0, tsnchange:CountyVersion_0, {'uris': ['tsn:hasCountyVersion']}], [tsnchange:CountyVersion_0, time:Interval_0, {'uris': ['tsn:referencePeriod']}], [tsnchange:CountyVersion_0, geo:Geometry_0, {'uris': ['geo:hasGeometry']}]]
# 3                                                                              [[tsnchange:County_0, tsnchange:CountyVersion_0, {'uris': ['tsn:hasCountyVersion']}], [tsnchange:CountyVersion_0, tsnchange:Change_0, {'uris': ['tsnchange:countyVersionAfter']}]]
# 4  [[tsnchange:County_0, tsnchange:CountyVersion_0, {'uris': ['tsn:hasCountyVersion']}], [tsnchange:CountyVersion_0, geo:Geometry_0, {'uris': ['geo:hasGeometry']}], [tsnchange:CountyVersion_0, tsnchange:Change_0, {'uris': ['tsnchange:countyVersionAfter']}]]
#
#   seed_node    seed_node_type  \
# 0        ?s     time:Interval
# 1        ?s  tsnchange:County
# 2        ?s      geo:Geometry
# 3        ?s  tsnchange:Change
# 4        ?s  tsnchange:County
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         sparql_queries  \
# 0  [{'comment': 'initial', 'sparql_query': 'PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX tsn: <http://purl.org/net/tsn#>
# PREFIX tsnchange: <http://purl.org/net/tsnchange#>
#
# SELECT DISTINCT ?x0 {
#  ?x0 rdf:type tsnchange:County .
#  ?x1 rdf:type tsnchange:CountyVersion .
#  ?x0 tsn:hasCountyVersion ?x1 .
#  ?x1 tsn:referencePeriod ?s .
# }'}, {'comment': 'added random seed node', 'sparql_query': 'PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX tsn: <http://purl.org/ne...
# 1  [{'comment': 'initial', 'sparql_query': 'PREFIX geo: <http://www.opengis.net/ont/geosparql#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX tsn: <http://purl.org/net/tsn#>
# PREFIX tsnchange: <http://purl.org/net/tsnchange#>
#
# SELECT DISTINCT ?x2 {
#  ?x1 rdf:type tsnchange:CountyVersion .
#  ?x2 rdf:type geo:Geometry .
#  ?s tsn:hasCountyVersion ?x1 .
#  ?x1 geo:hasGeometry ?x2 .
# }'}, {'comment': 'added random seed node', 'sparql_query': 'PREFIX geo: <http://www.opengis.net/ont/geosp...
# 2  [{'comment': 'initial', 'sparql_query': 'PREFIX geo: <http://www.opengis.net/ont/geosparql#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX time: <http://www.w3.org/2006/time#>
# PREFIX tsn: <http://purl.org/net/tsn#>
# PREFIX tsnchange: <http://purl.org/net/tsnchange#>
#
# SELECT DISTINCT ?x0 ?x2 {
#  ?x0 rdf:type tsnchange:County .
#  ?x1 rdf:type tsnchange:CountyVersion .
#  ?x2 rdf:type time:Interval .
#  ?x0 tsn:hasCountyVersion ?x1 .
#  ?x1 tsn:referencePeriod ?x2 .
#  ?x1 geo:hasGeomet...
# 3  [{'comment': 'initial', 'sparql_query': 'PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX tsn: <http://purl.org/net/tsn#>
# PREFIX tsnchange: <http://purl.org/net/tsnchange#>
#
# SELECT DISTINCT ?x0 {
#  ?x0 rdf:type tsnchange:County .
#  ?x1 rdf:type tsnchange:CountyVersion .
#  ?x0 tsn:hasCountyVersion ?x1 .
#  ?x1 tsnchange:countyVersionAfter ?s .
# }'}, {'comment': 'added random seed node', 'sparql_query': 'PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX tsn: <http://pu...
# 4  [{'comment': 'initial', 'sparql_query': 'PREFIX geo: <http://www.opengis.net/ont/geosparql#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX tsn: <http://purl.org/net/tsn#>
# PREFIX tsnchange: <http://purl.org/net/tsnchange#>
#
# SELECT DISTINCT ?x2 ?x3 {
#  ?x1 rdf:type tsnchange:CountyVersion .
#  ?x2 rdf:type geo:Geometry .
#  ?x3 rdf:type tsnchange:Change .
#  ?s tsn:hasCountyVersion ?x1 .
#  ?x1 geo:hasGeometry ?x2 .
#  ?x1 tsnchange:countyVersionAfter ?x3 .
# }'}, {'comment': 'added rand...
#
#    time_diff  \
# 0   0.716931
# 1   0.108962
# 2   0.386080
# 3   0.614221
# 4   0.123078
#
#                                                                                                    uri_changes  \
# 0               [{'placeholder': '?s', 'uri': 'http://time-space-event.com/resource/county/interval/id/7060'}]
# 1                 [{'placeholder': '?s', 'uri': 'http://time-space-event.com/resource/Texas/County/TX_NCA_5'}]
# 2  [{'placeholder': '?s', 'uri': 'http://time-space-event.com/resource/Alabama/County/MORGAN_3/Geometry/646'}]
# 3          [{'placeholder': '?s', 'uri': 'http://time-space-event.com/resource/South_Carolina/change_YORK_3'}]
# 4     [{'placeholder': '?s', 'uri': 'http://time-space-event.com/resource/Southwest_Territory/County/SEVIER'}]
#
#                   within_nodes
# 0  [tsnchange:CountyVersion_0]
# 1  [tsnchange:CountyVersion_0]
# 2  [tsnchange:CountyVersion_0]
# 3  [tsnchange:CountyVersion_0]
# 4  [tsnchange:CountyVersion_0]

# %%
def is_date(string, fuzzy=False):
    """
    Return whether the string can be interpreted as a date.

    :param string: str, string to check for date
    :param fuzzy: bool, ignore unknown tokens in string if True
    """
    try: 
        parse(string, fuzzy=fuzzy)
        return True

    except ValueError:
        return False

# %%
class queries_data:
    def __init__(self):
        self.processed_df = pd.DataFrame(data = None, 
                               columns = ['Q_id','Instances','Query_type', 'Predicates', "Filters"],
                              )
    
    def extract_query_type(self, leaf_nodes, node_types):
        type_list=[node_types[x] for x in leaf_nodes]
        return type_list[0]

    def uri_2_name(self, uri):
        return uri.split("/")[-1].title().replace("_"," ")

    def extract_instances(self, row):
        instance_list=[] #Needs to be a list because you are going to have many instances
        #Now Simon has only one instance
        d={}
        d["type"]=row["seed_node_type"]
        d_value=row["uri_changes"][0]["uri"]
        if d['type']=="tsnchange:County" or d['type']=="tsnchange:State":
            d_value=self.uri_2_name(d_value)
        d['value']=d_value
        instance_list.append(d)
        return instance_list
    
    def extract_predicates(self, row):
        predicates=[]
        for x in row["query_graph"]["edges"]:
            predicates.append(x[1])
        return predicates

    def extract_filter(self, row):
        filters=[]
        for f in row:
            d={}
            f_type=f["filter_type"]
            if f_type=="temporal":
                components=f["sparql_line"].replace('(', '').replace(')', '').split(' ')[1:4]
                if components[0][0]=='?' and components[2][0]=='?':
                    d["type"]=f_type
                else:
                    d["type"]="temporal_date"
                d['f_relation']=f["temporal_relation"]        
            elif f_type=="spatial":
                d["type"]=f["filter_type"]
                components=f["sparql_line"].replace('(', ' ').replace(')', ' ').split(' ')[1:4]
                d['f_relation']=components[0]

            d['Filter_components']=components
            
            filters.append(d)
        return filters 

    def extract_data(self, original_dataframe):
        print(original_dataframe.columns)
        self.processed_df['Q_id']= original_dataframe["rule"].apply(lambda x: x["id"])
        self.processed_df['Query_type']= original_dataframe.apply(lambda x: self.extract_query_type(x[2],x[3]), axis=1)
        self.processed_df['Instances']= original_dataframe.apply(lambda row: self.extract_instances(row),axis=1)
        self.processed_df['Predicates']= original_dataframe.apply(lambda row: self.extract_predicates(row),axis=1)
        self.processed_df['Filters']= original_dataframe.apply(lambda row: self.extract_filter(row["filters"]),axis=1)
        # print(original_dataframe.head())
        print(self.processed_df.head())
        return self.processed_df

# %%
q_d=queries_data()

queries_df=q_d.extract_data(data)

print(queries_df.Query_type.unique())
# Out:
# Index(['class_changes', 'filters', 'leaf_nodes', 'node_types', 'placeholders',
#        'query_graph', 'results', 'rule', 'rule_graph', 'rule_graph_edges',
#        'seed_node', 'seed_node_type', 'sparql_queries', 'time_diff',
#        'uri_changes', 'within_nodes'],
#       dtype='object')
#   Q_id  \
# 0   Q1
# 1   Q2
# 2   Q3
# 3   Q4
# 4   Q7
#
#                                                                                                           Instances  \
# 0              [{'type': 'time:Interval', 'value': 'http://time-space-event.com/resource/county/interval/id/7060'}]
# 1                                                               [{'type': 'tsnchange:County', 'value': 'Tx Nca 5'}]
# 2  [{'type': 'geo:Geometry', 'value': 'http://time-space-event.com/resource/Alabama/County/MORGAN_3/Geometry/646'}]
# 3      [{'type': 'tsnchange:Change', 'value': 'http://time-space-event.com/resource/South_Carolina/change_YORK_3'}]
# 4                                                                 [{'type': 'tsnchange:County', 'value': 'Sevier'}]
#
#          Query_type  \
# 0  tsnchange:County
# 1      geo:Geometry
# 2  tsnchange:County
# 3  tsnchange:County
# 4      geo:Geometry
#
#                                                               Predicates  \
# 0                            [tsn:hasCountyVersion, tsn:referencePeriod]
# 1                                [tsn:hasCountyVersion, geo:hasGeometry]
# 2           [tsn:hasCountyVersion, tsn:referencePeriod, geo:hasGeometry]
# 3                   [tsn:hasCountyVersion, tsnchange:countyVersionAfter]
# 4  [tsn:hasCountyVersion, geo:hasGeometry, tsnchange:countyVersionAfter]
#
#   Filters
# 0      []
# 1      []
# 2      []
# 3      []
# 4      []
# ['tsnchange:County' 'geo:Geometry' 'tsnchange:Change' 'sem:Event'
#  'time:Interval' 'tsnchange:State']

# %%
question_data = pd.read_csv("./Question_templatesV5.csv")
print(question_data.head())
# Out:
#   Q_type  Answer  \
# 0     Q1  COUNTY
# 1     Q1  COUNTY
# 2     Q1  COUNTY
# 3     Q1  COUNTY
# 4     Q1  COUNTY
#
#                                                Questions Template  \
# 0                                        Return all the counties.
# 1           Give the names of the counties that have been formed.
# 2           Name every county which has been founded until today.
# 3  List all the counties which have been created through history.
# 4                            Which counties do not exist anymore?
#
#    COUNTY_NAME  DATE_NAME  COUNTY_RELATION  CHANGE_TYPE  COUNTY_NAME_2  \
# 0        False      False            False        False          False
# 1        False      False            False        False          False
# 2        False      False            False        False          False
# 3        False      False            False        False          False
# 4        False      False            False        False          False
#
#    STATE_NAME  TEMP_RELATION  GEO_RELATION   PREDICATE
# 0       False          False         False  start_date
# 1       False          False         False  start_date
# 2       False          False         False  start_date
# 3       False          False         False  start_date
# 4       False          False         False    end_date

# %%
class question_template_picker:
    def __init__(self, question_templates):
        self.question_df = pd.DataFrame(data = None, 
                               columns = ['Questions'],
                              )
        self.question_templates=question_templates

    def predicate_filtering(self, questions_temp, row):
        if "tsnchange:countyVersionAfter" in row["Predicates"]:
            questions_temp=questions_temp[questions_temp["PREDICATE"]=="AFTER"]
        elif "tsnchange:countyVersionBefore" in row["Predicates"]:
            questions_temp=questions_temp[questions_temp["PREDICATE"]=="BEFORE"]    
        return questions_temp

    def filtering_question_templates(self, inst_type, row):
        questions_temp=self.question_templates[self.question_templates["Q_type"]==row["Q_id"]]
        questions_temp=questions_temp[questions_temp["Answer"]==Dict_query_type_mapping[row["Query_type"]]]
        questions_temp=questions_temp[questions_temp[Dict_instances_type_mapping[inst_type]]]
        f_list= row['Filters']
        f_types=[]
        if f_list:
            f_types=[d["type"] for d in f_list]

        if "temporal" in f_types:
            questions_temp=questions_temp[questions_temp["TEMP_RELATION"]]
        elif "spatial" in f_types:
            questions_temp=questions_temp[questions_temp["GEO_RELATION"]]
        
        questions_temp=self.predicate_filtering(questions_temp, row)
        return questions_temp  

    def template_picker(self, row):
        I_types=set(Dict_instances_type_mapping.keys())
        inst_list=row["Instances"]
        for i in inst_list:
            inst_type=i["type"]
            if inst_type not in Dict_instances_type_mapping.keys():
                return []
            if inst_type in I_types:
                I_types.remove(inst_type)
            questions_temp=self.filtering_question_templates(inst_type, row)
        for t in I_types:
            questions_temp=questions_temp[~questions_temp[Dict_instances_type_mapping[t]]]
        return list(questions_temp["Questions Template"].values)

    def question_template_production(self, querie_df):
        querie_df["Question_templates"]=querie_df.apply(lambda row: self.template_picker(row), axis=1)
        # print(querie_df["Question_templates"])
        return querie_df

# %%
q_t_p=question_template_picker(question_data)

df_question_templates=q_t_p.question_template_production(queries_df)
df_question_templates=df_question_templates[df_question_templates.astype(str)["Question_templates"]!='[]']

# %%
# df_question_templates.to_csv("./dataset.csv")

# %%
class question_production:
    def __init__(self, df_picked_templates):
        self.df_questions=df_picked_templates.copy()


    def replace_variables(self, row):
        if not row["Question_templates"]:
            return " "
        question_temp=random.choice(row["Question_templates"])
        for d in row["Instances"]:
            question=question_temp.replace(Dict_instances_type_mapping[d["type"]],  d["value"])
        return question  

    def produce_questions(self):
        self.df_questions["Questions"]=self.df_questions.apply(lambda row: self.replace_variables(row), axis=1)
        return self.df_questions

# %%
from happytransformer import HappyTextToText, TTSettings

happy_tt = HappyTextToText("T5", "vennify/t5-base-grammar-correction")

args = TTSettings(num_beams=5, min_length=1,max_length=100,early_stopping=True)

def grammar_correction(question_list):
    corrected_question_list=[]
    print(question_list)
    for text in question_list:
        corrected_text= happy_tt.generate_text("grammar: "+text, args=args).text
        if text!=corrected_text:
            corrected_question_list.append(corrected_text)
        else:
            corrected_question_list.append("")
    return corrected_question_list


#result = happy_tt.generate_text("grammar: This sentences has has bads grammar.", args=args)
# Out:
# 10/26/2022 14:05:43 - INFO - happytransformer.happy_transformer -   Using model: cuda

# %%
q_p=question_production(df_question_templates)
question_df=q_p.produce_questions()

#question_df["Correction"]=question_df["Questions"].apply(lambda x: grammar_correction(x))

question_df.to_csv("./dataset3.csv")
# Out:
# Which counties have been extinct http://time-space-event.com/resource/county/interval/id/7060?
# c:\Users\mikem\anaconda3\lib\site-packages\transformers\pipelines\base.py:997: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30964/1948025006.py in <module>
#       2 question_df=q_p.produce_questions()
#       3
# ----> 4 question_df["Correction"]=question_df["Questions"].apply(lambda x: grammar_correction(x))
#       5
#       6 question_df.to_csv("./dataset3.csv")
#
# c:\Users\mikem\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# c:\Users\mikem\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# c:\Users\mikem\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097                 # "Callable[[Any], Any]"
# -> 1098                 mapped = lib.map_infer(
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
#
# c:\Users\mikem\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp/ipykernel_30964/1948025006.py in <lambda>(x)
#       2 question_df=q_p.produce_questions()
#       3
# ----> 4 question_df["Correction"]=question_df["Questions"].apply(lambda x: grammar_correction(x))
#       5
#       6 question_df.to_csv("./dataset3.csv")
#
# ~\AppData\Local\Temp/ipykernel_30964/2687464726.py in grammar_correction(question_list)
#       9     print(question_list)
#      10     for text in question_list:
# ---> 11         corrected_text= happy_tt.generate_text("grammar: "+text, args=args).text
#      12         if text!=corrected_text:
#      13             corrected_question_list.append(corrected_text)
#
# c:\Users\mikem\anaconda3\lib\site-packages\happytransformer\happy_text_to_text.py in generate_text(self, text, args)
#      84         self.__assert_default_text_is_val(text)
#      85
# ---> 86         output = self._pipeline(text, min_length=args.min_length,
#      87                                 max_length=args.max_length,
#      88                                 do_sample=args.do_sample,
#
# c:\Users\mikem\anaconda3\lib\site-packages\transformers\pipelines\text2text_generation.py in __call__(self, *args, **kwargs)
#     136         """
#     137
# --> 138         result = super().__call__(*args, **kwargs)
#     139         if (
#     140             isinstance(args[0], list)
#
# c:\Users\mikem\anaconda3\lib\site-packages\transformers\pipelines\base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1025             return self.iterate(inputs, preprocess_params, forward_params, postprocess_params)
#    1026         else:
# -> 1027             return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#    1028
#    1029     def run_multi(self, inputs, preprocess_params, forward_params, postprocess_params):
#
# c:\Users\mikem\anaconda3\lib\site-packages\transformers\pipelines\base.py in run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1032     def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1033         model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1034         model_outputs = self.forward(model_inputs, **forward_params)
#    1035         outputs = self.postprocess(model_outputs, **postprocess_params)
#    1036         return outputs
#
# c:\Users\mikem\anaconda3\lib\site-packages\transformers\pipelines\base.py in forward(self, model_inputs, **forward_params)
#     942                 with inference_context():
#     943                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# --> 944                     model_outputs = self._forward(model_inputs, **forward_params)
#     945                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#     946             else:
#
# c:\Users\mikem\anaconda3\lib\site-packages\transformers\pipelines\text2text_generation.py in _forward(self, model_inputs, **generate_kwargs)
#     158         generate_kwargs["max_length"] = generate_kwargs.get("max_length", self.model.config.max_length)
#     159         self.check_inputs(input_length, generate_kwargs["min_length"], generate_kwargs["max_length"])
# --> 160         output_ids = self.model.generate(**model_inputs, **generate_kwargs)
#     161         out_b = output_ids.shape[0]
#     162         if self.framework == "pt":
#
# c:\Users\mikem\anaconda3\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# c:\Users\mikem\anaconda3\lib\site-packages\transformers\generation_utils.py in generate(self, inputs, max_length, min_length, do_sample, early_stopping, num_beams, temperature, top_k, top_p, typical_p, repetition_penalty, bad_words_ids, bos_token_id, pad_token_id, eos_token_id, length_penalty, no_repeat_ngram_size, encoder_no_repeat_ngram_size, num_return_sequences, max_time, max_new_tokens, decoder_start_token_id, use_cache, num_beam_groups, diversity_penalty, prefix_allowed_tokens_fn, logits_processor, stopping_criteria, constraints, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, forced_bos_token_id, forced_eos_token_id, remove_invalid_values, synced_gpus, **model_kwargs)
#    1249             )
#    1250             # 12. run beam search
# -> 1251             return self.beam_search(
#    1252                 input_ids,
#    1253                 beam_scorer,
#
# c:\Users\mikem\anaconda3\lib\site-packages\transformers\generation_utils.py in beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, **model_kwargs)
#    2033             model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2034
# -> 2035             outputs = self(
#    2036                 **model_inputs,
#    2037                 return_dict=True,
#
# c:\Users\mikem\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\Users\mikem\anaconda3\lib\site-packages\transformers\models\t5\modeling_t5.py in forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1633
#    1634         # Decode
# -> 1635         decoder_outputs = self.decoder(
#    1636             input_ids=decoder_input_ids,
#    1637             attention_mask=decoder_attention_mask,
#
# c:\Users\mikem\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\Users\mikem\anaconda3\lib\site-packages\transformers\models\t5\modeling_t5.py in forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1028                 )
#    1029             else:
# -> 1030                 layer_outputs = layer_module(
#    1031                     hidden_states,
#    1032                     attention_mask=extended_attention_mask,
#
# c:\Users\mikem\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\Users\mikem\anaconda3\lib\site-packages\transformers\models\t5\modeling_t5.py in forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict)
#     689                 query_length = None
#     690
# --> 691             cross_attention_outputs = self.layer[1](
#     692                 hidden_states,
#     693                 key_value_states=encoder_hidden_states,
#
# c:\Users\mikem\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\Users\mikem\anaconda3\lib\site-packages\transformers\models\t5\modeling_t5.py in forward(self, hidden_states, key_value_states, attention_mask, position_bias, layer_head_mask, past_key_value, use_cache, query_length, output_attentions)
#     604     ):
#     605         normed_hidden_states = self.layer_norm(hidden_states)
# --> 606         attention_output = self.EncDecAttention(
#     607             normed_hidden_states,
#     608             mask=attention_mask,
#
# c:\Users\mikem\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\Users\mikem\anaconda3\lib\site-packages\transformers\models\t5\modeling_t5.py in forward(self, hidden_states, mask, key_value_states, position_bias, past_key_value, layer_head_mask, query_length, use_cache, output_attentions)
#     542
#     543         attn_output = unshape(torch.matmul(attn_weights, value_states))  # (batch_size, seq_length, dim)
# --> 544         attn_output = self.o(attn_output)
#     545
#     546         present_key_value_state = (key_states, value_states) if (self.is_decoder and use_cache) else None
#
# c:\Users\mikem\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\Users\mikem\anaconda3\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#     101
#     102     def forward(self, input: Tensor) -> Tensor:
# --> 103         return F.linear(input, self.weight, self.bias)
#     104
#     105     def extra_repr(self) -> str:
#
# c:\Users\mikem\anaconda3\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1846     if has_torch_function_variadic(input, weight, bias):
#    1847         return handle_torch_function(linear, (input, weight, bias), input, weight, bias=bias)
# -> 1848     return torch._C._nn.linear(input, weight, bias)
#    1849
#    1850
#
# KeyboardInterrupt:
